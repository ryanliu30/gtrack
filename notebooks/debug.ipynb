# %%
# %load_ext autoreload
# %autoreload 2

# %%
import gtrack
import numpy as np
import pandas as pd

# %%
from gtrack.utils import TracksDataset, collate_fn
from torch.utils.data import DataLoader

# %%
event = next(TracksDataset(
    hole_inefficiency= 0.1,
    d0= 0.1,
    noise= 0.1,
    minbias_num_dist= [50, None, "poisson"],
    minbias_pt_dist= [1, 5],
    pileup_num_dist= [45, None, "poisson"],
    pileup_pt_dist= [1, 5],
    hard_proc_num_dist= [5, None, "poisson"],
    hard_proc_pt_dist= [100, 5, "normal"],
))
print(event[2])
event[3].display()
# Out:
# tensor([0.])
